# %%
from TwitterSearch import *
try:

    ts = TwitterSearch(
        consumer_key = 'x04WFoj6t4NOqKe8E5uZi2fJ8',
        consumer_secret = 'tPdlkgNvOpFN3wEo5NlwJsExUmB8XgYb66vnoG4eQGk35ikyZN',
        access_token = '1079501311-ulVd9UB2jCBjSIbEnacmweUU0cEKmFqpjrvfOCr',
        access_token_secret = 'pCUsRxldnj8jTvcIPk226QOPkhzGbsVkoDkmdLbBZMiyf'
     )

    tso = TwitterSearchOrder()
    tso.set_keywords(['#SPFC'])
    tso.set_language('pt')

    for tweet in ts.search_tweets_iterable(tso):
        print( '@%s tweeted: %s' % ( tweet['user']['screen_name'], tweet['text'] ) )

except TwitterSearchException as e:
    print(e)
# Out:
# @M1totricolor_FC tweeted: Henrique prevê “guerra” no bom sentido. Jucilei vê boa vantagem em Itaquera #SPFC 🔴⚪⚫ https://t.co/zNX2cuUjmk
# @Castolo90 tweeted: RT @andrechuahy: Rodrigo Caio, tem que ser banco hoje. Motivos:
# 1) Bruno Alves está jogando muito bem e com muita seriedade.
# 2) R. Caio pra…
# @well9989 tweeted: RT @InterativoSPFC: A mídia vive falando de tabu, então vamos a um:
#
# O São Paulo jamais perdeu um duelo eliminatório no Majestoso quando sa…
# @EitaKaroll tweeted: RT @SaoPaulinoRaiz: @loucosdobandoo #QuartaDetremuraSDV Primeiramente Bom dia Carrile
# Segundamente HOJE TEM SÃO PAULO 🔴⚪⚫
# Pra cima delas me…
# @well9989 tweeted: RT @InterativoSPFC: Texto violento, rancoroso, nojento, podre, fétido. Verdadeiro lixo incitando violência para o majestoso em Itaquera, Co…
# @Castolo90 tweeted: RT @Bettosp_71: Família de torcedor morto no Morumbi em 2017 processa o São Paulo e FPF https://t.co/Mv6J0maDWc via @UOLEsporte @UOL #SPFC
# ...

# %%
e
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9ffbf43126e3> in <module>()
# ----> 1 e
#
# NameError: name 'e' is not defined
